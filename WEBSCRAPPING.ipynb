# %% [markdown]
# # Installing Request

# %%
! pip install requests

# %%
''' request module 
Request module  is used for making https request to specific url and returns the responsee 
python request provides inbuilt functionalities for managing both request and responsee'''
# Out:
# ' request module \nRequest module  is used for making https request to specific url and returns the responsee \npython request provides inbuilt functionalities for managing both request and responsee'

# %%
''' Beatiful Soup is  used to extract information from html and  xml files.
it provides a parse tree and information to navigate , search and modify this parse tree.
Beatiful Soup is a python lib used to used to pull data from html and xml files  for  web scrapping  purpose.
it provides parse tree from page source code that can be utilized  to drag data hierarchically and more 
legibly.'''
# Out:
#   Cell In[3], line 1
#     ''' Beatiful Soup is  used to extract information from html and  xml files.
#     ^
# _IncompleteInputError: incomplete input

# %%
# !pip install bs4

# %%
from bs4 import BeautifulSoup as soup

# %%
from urllib.request import urlopen as uReq

# %%
my_url='https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %%
uClient= uReq(my_url)

# %%
page_html=uClient.read()
uClient.close()

# %%
page_html
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.aa1465.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.fbaef9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="ap
# ...

# %%
page_soup=soup(page_html,'html.parser')

# %%
page_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
containers= page_soup.find_all('div', { 'class' : 'nZIRY7'})
len(containers)
# Out:
# 24

# %%
soup.prettify(containers[0])
# Out:
# '<div class="nZIRY7">\n <div data-id="MOBH4DQFSY9ETDUU" style="width:100%">\n  <div class="jIjQ8S">\n   <a class="k7wcnx" href="/apple-iphone-16-teal-128-gb/p/itmce4bb3f55cc2f?pid=MOBH4DQFSY9ETDUU&amp;lid=LSTMOBH4DQFSY9ETDUUI6AN3O&amp;marketplace=FLIPKART&amp;q=iphone&amp;store=tyy%2F4io&amp;spotlightTagId=default_BestsellerId_tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=ba20ec9a-134c-4d17-83ae-fa91f0f8e24c.MOBH4DQFSY9ETDUU.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=8cf5s85ga80000001765861469753&amp;qH=0b3f45b266a97d70" rel="noopener noreferrer" target="_blank">\n    <div>\n    </div>\n    <div class="T6hTMI">\n     <div class="R7Cntx">\n      <div>\n       <div class="lWX0_T" style="height:200px;width:200px">\n        <img alt="Apple iPhone 16 (Teal, 128 GB)" class="UCc1lI" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/o/l/2/-original-imahgfmzvanpgncf.jpeg?q=70"/>\n       </div>\n      </div>\n     </div>\n 
# ...

# %%
price_containers= page_soup.find_all('div', { 'class' : 'hZ3P6w DeU9vF'})
len(price_containers)
# Out:
# 24

# %%
a=price_containers[2].text

# %%
a
# Out:
# '₹79,900'

# %%
trim_price=''.join(a.split(','))
trim_price
# Out:
# '₹79900'

# %%
rm_price=trim_price.split('₹')
rm_price
# Out:
# ['', '79900']

# %%
add_rs_price = 'Rs'+ rm_price[1]
add_rs_price
# Out:
# 'Rs79900'

# %%
name_containers = page_soup.find_all('div' , { 'class' : 'RG5Slk'})
len(name_containers)
# Out:
# 24

# %%
name_containers[0].text
# Out:
# 'Apple iPhone 16 (Teal, 128 GB)'

# %%
rating_containers = page_soup.find_all('div', {'class' : 'MKiFS6'})
len(rating_containers)
# Out:
# 39

# %%
rating_containers[0].text
# Out:
# '4.6'

# %%
rating_containers[38].text
# Out:
# '5'

# %%
# prepare the file for dumping the  data

# %%
filename = 'product.csv'
f=open(filename , 'w' , encoding='utf-8')
headers= 'name , pricing , rating' 
f.write(headers)
# Out:
# 23
